# %%
import numpy as np
import pandas as pd
df = pd.read_csv("https://drive.usercontent.google.com/download?id=1_8iUr3J8BOc3aBlsB6Jt4--OUb4hd6e8&export=download&authuser=0&confirm=t&uuid=080d4ac6-d7e9-4abe-852f-dfff93eda612&at=APZUnTUL71DIMzsq0AE5SEHdSsfV:1721117421100")

# %%
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# ##### Pandas offers 5 primary methods to select items:
#
#  1] Dot notation : Select a single column
#
#  2] loc  : location : select data based on label (row name , column name)
#
#  3] iloc : integer location - index based
#
#  4] at  : select one item only based on row and column label
#
#  5] iat   : select one item only based on row and column number

# %% [markdown]
# ### Dot Notation

# %% [markdown]
# Select one column only as reference
#
# Syntax - dataframe.column_name

# %%
df.state
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: state, Length: 3333, dtype: object

# %% [markdown]
# The object returned on selecting just one column is a pandas series

# %%
type(df.state)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## .loc

# %% [markdown]
# loc - label based - selects data based on labels or a boolean array
#
# loc - used for selecting data from a dataframe
#
# .loc takes 2 arguments inside the square brackets.
#
# 1] row name - label
#
# 2] column name - header
#
# ##### Syntax - dataframe.loc['row_name', 'column_name']
#
# When slicing, It doesn't include end value

# %% [markdown]
# #### Selecting single row by label

# %%
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
df.loc[1]
# Out:
# state                           OH
# account length                 107
# area code                      415
# phone number              371-7191
# international plan              no
# voice mail plan                yes
# number vmail messages           26
# total day minutes            161.6
# total day calls                123
# total day charge             27.47
# total eve minutes            195.5
# total eve calls                103
# total eve charge             16.62
# total night minutes          254.4
# total night calls              103
# total night charge           11.45
# total intl minutes            13.7
# total intl calls                 3
# total intl charge              3.7
# customer service calls           1
# churn                        False
# Name: 1, dtype: object

# %% [markdown]
# #### Selecting multiple rows by label

# %%
df.loc[[1,2]]
# Out:
#   state  account length  area code phone number international plan  \
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
#
#    total day charge  ...  total eve calls  total eve charge  \
# 1             27.47  ...              103             16.62
# 2             41.38  ...              110             10.30
#
#    total night minutes  total night calls  total night charge  \
# 1                254.4                103               11.45
# 2                162.6                104                7.32
#
#    total intl minutes  total intl calls  total intl charge  \
# 1                13.7                 3               3.70
# ...

# %% [markdown]
# #### Selecting rows and specific columns by labels

# %%
df.loc[1, ['area code', 'state']]
# Out:
# area code    415
# state         OH
# Name: 1, dtype: object

# %% [markdown]
# #### Slicing rows and columns by labels:

# %%
df.loc[1:5, ['state', 'area code']]
# Out:
#   state  area code
# 1    OH        415
# 2    NJ        415
# 3    OH        408
# 4    OK        415
# 5    AL        510

# %% [markdown]
# ## .iloc

# %% [markdown]
# Integer position-based: select data based on index.
#
# Syntax: df.iloc[rows, columns]
#
# Does not include end: When slicing, it excludes the end value.

# %% [markdown]
# #### Selecting a single row by index

# %%
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
df.iloc[0]
# Out:
# state                           KS
# account length                 128
# area code                      415
# phone number              382-4657
# international plan              no
# voice mail plan                yes
# number vmail messages           25
# total day minutes            265.1
# total day calls                110
# total day charge             45.07
# total eve minutes            197.4
# total eve calls                 99
# total eve charge             16.78
# total night minutes          244.7
# total night calls               91
# total night charge           11.01
# total intl minutes            10.0
# total intl calls                 3
# total intl charge              2.7
# customer service calls           1
# churn                        False
# Name: 0, dtype: object

# %% [markdown]
# #### Selecting multiple rows by index:

# %%
df.iloc[[0,1]]   # First row , Second row
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3                2.7
# ...

# %% [markdown]
# #### Selecting rows and specific columns by index:

# %%
df.iloc[0, [0,1,2]]
# Out:
# state              KS
# account length    128
# area code         415
# Name: 0, dtype: object

# %% [markdown]
# #### Slicing rows and columns by index

# %%
df.iloc[0:3 , 0:4]
# Out:
#   state  account length  area code phone number
# 0    KS             128        415     382-4657
# 1    OH             107        415     371-7191
# 2    NJ             137        415     358-1921

# %% [markdown]
# ## Comparison

# %% [markdown]
# loc is generally used when you want to work with labels, which are more meaningful and easier to understand.
#
# iloc is generally used when you want to work with position

# %% [markdown]
# ### at

# %% [markdown]
# Label based scalar accessor
#
# It is used to access a single value using row label & column label
#
# df.at[row_label, column_label]
#
# scalar  - single value / single element

# %%
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
df.iat[1, 1]
# Out:
# 107

# %%
df.iat[2,1]
# Out:
# 137

# %% [markdown]
# ### .iat

# %% [markdown]
# integer location based scalar accessor
#
# It is used to access a single value using row indices & column indices
#
# df.at[row_indices, column_indices]

# %%
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
df.iat[0,2]
# Out:
# 415
